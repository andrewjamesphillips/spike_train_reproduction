# %% [markdown]
# # Run Spike Train Reproduction Experiment

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Volumes/Lab/Users/ajphillips/spike_train_reproduction/')
import experiment as spike_train_reproduction

# %%
# Initialize an experiment.
experiment = spike_train_reproduction.Experiment(piece="2025-01-22-1", board=519, server="bertha", cell_types=["alpha"], single_elec_reps=15)
# Out:
# Board: 519
# Piece: 2025-01-22-1
# Raw data path: /Volumes/Stream/Data/RETINA/Stream/2025-01-22-1
# Stream data path: /Volumes/Stream/Data/RETINA/2025-01-22-1
# Analysis path: /Volumes/Stream/Analysis/RETINA/2025-01-22-1
# Bin file path: /Volumes/Acquisition/Data/electrical-stimuli/ajphillips/RETINA/2025-01-22-1
# Single electrode reps: 15

# %%
# experiment.raw_data_path = "/Volumes/Data/2024-10-02-2"
# experiment.stim_files = "/Volumes/Stream/Analysis/RETINA/2024-10-02-7/estim/single_elec_nlv_519_15_reps"

# %%
# Generate a single-electrode scan.
experiment.generate_single_electrode_scan(datarun="data005")
# Out:
# Generating SEF, SLF, SIF files for single electrode scan for 519 board with 15 repetitions at /Volumes/Stream/Analysis/RETINA/2025-01-22-1/estim/single_elec_nlv_519_15_reps
#
#                             < M A T L A B (R) >
#                   Copyright 1984-2014 The MathWorks, Inc.
#                     R2014a (8.3.0.532) 64-bit (glnxa64)
#                              February 11, 2014
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
# Running startup file....
# ...
# /home/vision/Sasi/matlab/code/projects/electrical_stim/scripts
# > In path at 109
#   In addpath at 86
#   In matlabrc at 210
# Passed stimulation safety window check
# Experiment will take 3226.615050 seconds.
# Generating BIN file at /Volumes/Stream/Analysis/RETINA/2025-01-22-1/estim
# Verbose mode on.
# Saving output to /Volumes/Stream/Analysis/RETINA/2025-01-22-1/estim/single_elec_nlv_519_15_reps.bin
# Preprocessing data
# ...

# %%
# Run Vision.
vision_streaming_proc = experiment.stream_vision(datarun="data002", wn="BW-8-4")

# %%
# Copy the Vision analysis.
experiment.copy_vision_analysis(wn_datarun="data003")
# Out:
# Copying Vision analysis from Acquisition to /Volumes/Stream/Analysis/RETINA/2025-01-22-1
# Loading white noise datarun data003...

# %%
# Open a subprocess to preprocess a single-electrode scan.
preprocess_proc = experiment.preprocess_single_electrode_scan(estim_datarun="data005")
# Out:
# Preprocessing single electrode scan to /Volumes/Stream/Analysis/RETINA/2025-01-22-1/data005
# bash /Volumes/Lab/Users/ajphillips/RETINA/shell/stream_sync.sh -i /Volumes/Stream/Data/RETINA/Stream/2025-01-22-1/data005/ -s /Volumes/Stream/Data/RETINA/2025-01-22-1/data005
# bash /Volumes/Lab/Users/ajphillips/RETINA/shell/preprocess_stream_bertha.sh -s /Volumes/Stream/Data/RETINA/2025-01-22-1/data005 -f /Volumes/Stream/Analysis/RETINA/2025-01-22-1/estim/single_elec_nlv_519_15_reps -o /Volumes/Stream/Analysis/RETINA/2025-01-22-1/data005 -n /Volumes/Lab/Users/praful/new-labview-io -e 1 -i None

# %%
# Open a subprocess to gsort a single-electrode scan.
gsort_proc = experiment.gsort(wn_datarun="data003", estim_datarun="data005") # figure out why gsort repeats amplitude when no new amplitudes ready
# Out:
# Running gsort on ['alpha'] using white noise datarun data003 at /Volumes/Stream/Analysis/RETINA/2025-01-22-1/gsort/data005
# gsort sees cell types as alpha
# /home/vision/anaconda3/envs/g-sort-bertha-main/lib/python3.8/site-packages/vision_utils-1.1.1-py3.8-linux-x86_64.egg/visionloader/__init__.py
# /Volumes/Stream/Analysis/RETINA/2025-01-22-1/data003
# /Volumes/Stream/Analysis/RETINA/2025-01-22-1/data005
# Directory found!
# 100%|██████████| 7/7 [00:10<00:00,  1.50s/it]
# 10.707231760025024
# 100%|██████████| 7/7 [00:02<00:00,  2.54it/s]
# 3.1016759872436523
# 100%|██████████| 7/7 [00:03<00:00,  2.29it/s]
# 3.4021520614624023
# 100%|██████████| 7/7 [00:03<00:00,  2.15it/s]
# 3.5550620555877686
# 100%|██████████| 7/7 [00:03<00:00,  2.18it/s]
# 3.524266481399536
# 100%|██████████| 7/7 [00:03<00:00,  2.15it/s]
# 3.5724546909332275
# 100%|██████████| 7/7 [00:03<00:00,  1.91it/s]
# 3.9676883220672607
# 100%|██████████| 7/7 [00:03<00:00,  1.93it/s]
# 3.983093500137329
# ...

# %%
# Check the status of a subprocess (None if still running, 0 if successful exit).
print(preprocess_proc.poll())
print(gsort_proc.poll())
# Out:
# 0
# 0

# %%
# Kill a subprocess.
experiment.kill_process(process=preprocess_proc)

# %%
# Run the bundle algorithm.
experiment.bundle_algo(wn_datarun="data003", estim_datarun="data005", save=True)
# Out:
# Computing bundle thresholds on single electrode datarun data005
# Generating params for elecs...
# Running bundle algorithm...
# --- Finished in 24.652310848236084 seconds ---
#
# Saving bundle thresholds to /Volumes/Stream/Analysis/RETINA/2025-01-22-1/dictionary/data003_bundle_thresholds.npz

# %%
print(experiment.bundle_thresholds[:30])
# Out:
# [[ 2. 17.]
#  [ 3. 41.]
#  [ 4. -1.]
#  [ 5. -1.]
#  [ 6. 41.]
#  [ 7. -1.]
#  [ 8. 26.]
#  [ 9. 21.]
#  [10.  8.]
#  [11. -1.]
#  [12. 35.]
#  [13. 30.]
#  [14. 11.]
#  [15. 18.]
#  [16. 14.]
#  [17. -1.]
#  [18. 39.]
#  [19. -1.]
#  [20. 31.]
#  [21. 30.]
#  [22. 26.]
#  [23. 28.]
#  [24. -1.]
#  [25. -1.]
#  [26. 13.]
#  [27. -1.]
#  [28. 17.]
#  [29. 14.]
#  [30. 10.]
#  [31. 25.]]

# %%
# Open a subprocess to run the Vision mapping analysis on visual stimulation data.
vision_mapping_proc = experiment.run_vision_mapping_analysis(wn_datarun="data000", vstim_datarun="data013")

# %%
# Check the status of a subprocess (None if still running, 0 if successful exit).
print(vision_mapping_proc.poll())

# %%
# Kill a subprocess.
experiment.kill_process(process=vision_mapping_proc)

# %% [markdown]
# Now go use `electrical_stim_selectivity.ipynb` and `stimulus_assigner.ipynb` to create the experiment scan.

# %%
# Build the SEF, SIF, SLF, and BIN files of the experiment scan.
experiment.make_litke_scan(label="_text_3")

# %%
spike_trains_preprocess_proc = experiment.preprocess_litke_scan(estim_datarun="data009", tasks=11, trials=15, whole=False, label="_text")

# %%
# Check the status of a subprocess (None if still running, 0 if successful exit).
print(spike_trains_preprocess_proc.poll())

# %%
experiment.kill_process(process=spike_trains_preprocess_proc)
