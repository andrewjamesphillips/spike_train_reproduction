# %% [markdown]
# # Build a map from electrodes to preprocessing patterns

# %%
# Imports
import numpy as np
import os
from tqdm import tqdm
from scipy.io import loadmat
import re

# %%
preprocess_path = f"/Volumes/Stream/Analysis/RETINA/2024-07-18-0/data004"

for frame in os.listdir(preprocess_path):

    print(f"{frame}")
    pattern_path = os.path.join(preprocess_path, frame, "pattern_files")
    electrodes_to_preprocess_patterns = [[] for _ in range(512)]

    # Find the stimulating electrodes for each preprocessing pattern
    for file in tqdm(os.listdir(pattern_path)):

        # Extract the preprocessing pattern from the file using regular expression
        pp_pattern = int(re.findall('\d+', file)[0])

        # Load the mat file
        mat = loadmat(os.path.join(pattern_path, file))

        # Get the stimulating electrodes
        stim_elecs = mat['patternStruct']['stimElecs'][0,0][:,0]

        for elec in stim_elecs:
            electrodes_to_preprocess_patterns[elec-1].append(pp_pattern)

    # Convert the list of lists to a numpy array
    electrodes_to_preprocess_patterns = np.array(electrodes_to_preprocess_patterns, dtype=object)

    # Save the numpy array
    np.save(os.path.join(preprocess_path, frame, "electrodes_to_preprocess_patterns.npy"), electrodes_to_preprocess_patterns, allow_pickle=True)
# Out:
# frame_1
# 100%|██████████| 1565/1565 [00:00<00:00, 2721.18it/s]
# frame_2
# 100%|██████████| 1501/1501 [00:00<00:00, 2653.45it/s]
# frame_23
# 100%|██████████| 116/116 [00:00<00:00, 2256.39it/s]
# frame_22
# 100%|██████████| 141/141 [00:00<00:00, 2564.77it/s]
# frame_19
# 100%|██████████| 135/135 [00:00<00:00, 2447.97it/s]
# frame_13
# 100%|██████████| 119/119 [00:00<00:00, 2633.10it/s]
# frame_0
# 100%|██████████| 1552/1552 [00:00<00:00, 2759.18it/s]
# frame_5
# 100%|██████████| 129/129 [00:00<00:00, 2467.37it/s]
# frame_17
# 100%|██████████| 141/141 [00:00<00:00, 2425.42it/s]
# frame_20
# 100%|██████████| 123/123 [00:00<00:00, 2609.85it/s]
# frame_6
# 100%|██████████| 116/116 [00:00<00:00, 2264.26it/s]
# frame_16
# 100%|██████████| 135/135 [00:00<00:00, 2585.87it/s]
# frame_11
# 100%|██████████| 125/125 [00:00<00:00, 2440.82it/s]
# frame_18
# 100%|██████████| 96/96 [00:00<00:00, 2527.23it/s]
# frame_3
# 100%|██████████| 1507/1507 [00:00<00:00, 2739.08it/s]
# frame_14
# 100%|██████████| 120/120 [00:00<00:00, 2526.98it/s]
# frame_4
# 100%|██████████| 118/118 [00:00<00:00, 2578.29it/s]
# frame_10
# 100%|██████████| 141/141 [00:00<00:00, 2455.29it/s]
# frame_8
# 100%|██████████| 145/145 [00:00<00:00, 2618.37it/s]
# frame_15
# 100%|██████████| 138/138 [00:00<00:00, 2514.23it/s]
# frame_12
# 100%|██████████| 133/133 [00:00<00:00, 2415.25it/s]
# frame_7
# 100%|██████████| 142/142 [00:00<00:00, 2461.13it/s]
# frame_21
# 100%|██████████| 144/144 [00:00<00:00, 2596.57it/s]
# frame_9
# 100%|██████████| 137/137 [00:00<00:00, 2440.22it/s]
